# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm
from sklearn.preprocessing import StandardScaler
from scipy import stats
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df_train = pd.read_csv('train.csv',index_col = 'Id')

# %%
df_train.head()
# Out:
#     MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1           60       RL         65.0     8450   Pave   NaN      Reg
# 2           20       RL         80.0     9600   Pave   NaN      Reg
# 3           60       RL         68.0    11250   Pave   NaN      IR1
# 4           70       RL         60.0     9550   Pave   NaN      IR1
# 5           60       RL         84.0    14260   Pave   NaN      IR1
#
#    LandContour Utilities LotConfig    ...     PoolArea PoolQC Fence  \
# Id                                    ...
# 1          Lvl    AllPub    Inside    ...            0    NaN   NaN
# 2          Lvl    AllPub       FR2    ...            0    NaN   NaN
# 3          Lvl    AllPub    Inside    ...            0    NaN   NaN
# 4          Lvl    AllPub    Corner    ...            0    NaN   NaN
# 5          Lvl    AllPub       FR2    ...            0    NaN   NaN
#
#    MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition  SalePrice
# Id
# ...

# %%
sns.distplot(df_train['SalePrice'])

# %%
data = pd.concat([df_train['SalePrice'],df_train['GrLivArea']],axis=1)

# %%
data.plot.scatter(x = 'GrLivArea',y = 'SalePrice')

# %%
df_train.plot.scatter('TotalBsmtSF','SalePrice')

# %%
sns.boxplot('OverallQual','SalePrice',data = df_train)
plt.show()

# %%
f, ax = plt.subplots(figsize=(16, 8))
fig = sns.boxplot(x='YearBuilt', y="SalePrice", data=df_train)
fig.axis(ymin=0, ymax=800000);
plt.xticks(rotation=90);

# %%
f,ax = plt.subplots(figsize = (15,9))
sns.heatmap(df_train.corr(),vmax=0.8,square=True)

# %%
cols = df_train.corr().nlargest(10,'SalePrice')['SalePrice'].index

sns.heatmap(df_train[cols].corr(),cbar=True,annot=True,square=True,fmt=
           '.2f',annot_kws={'size':10},yticklabels=cols.values,xticklabels=cols.values)
plt.show()

# %%
sns.set()
cols = ['SalePrice', 'OverallQual', 'GrLivArea', 'GarageCars', 'TotalBsmtSF', 'FullBath', 'YearBuilt']
sns.pairplot(df_train[cols],size = 2.5)
plt.show()

# %%
df_train.isna().sum().sort_values(ascending = False)
# Out:
# PoolQC           1453
# MiscFeature      1406
# Alley            1369
# Fence            1179
# FireplaceQu       690
# LotFrontage       259
# GarageType         81
# GarageCond         81
# GarageFinish       81
# GarageQual         81
# GarageYrBlt        81
# BsmtFinType2       38
# BsmtExposure       38
# BsmtQual           37
# BsmtCond           37
# BsmtFinType1       37
# MasVnrArea          8
# MasVnrType          8
# Electrical          1
# RoofMatl            0
# Exterior1st         0
# RoofStyle           0
# ExterQual           0
# Exterior2nd         0
# YearBuilt           0
# ExterCond           0
# Foundation          0
# YearRemodAdd        0
# SalePrice           0
# OverallCond         0
#                  ...
# GarageArea          0
# PavedDrive          0
# WoodDeckSF          0
# OpenPorchSF         0
# 3SsnPorch           0
# BsmtUnfSF           0
# ScreenPorch         0
# PoolArea            0
# MiscVal             0
# MoSold              0
# ...

# %%
miss = pd.DataFrame((df_train.isna().sum()/df_train.shape[0]).sort_values(ascending = False),columns=['miss_rate'])

# %%
saleprice_scaled = StandardScaler().fit_transform(df_train['SalePrice'][:,np.newaxis])
low_range = saleprice_scaled[saleprice_scaled[:,0].argsort()][:10]
print(low_range)
# Out:
# [[-1.83870376]
#  [-1.83352844]
#  [-1.80092766]
#  [-1.78329881]
#  [-1.77448439]
#  [-1.62337999]
#  [-1.61708398]
#  [-1.58560389]
#  [-1.58560389]
#  [-1.5731    ]]

# %%
high_range= saleprice_scaled[saleprice_scaled[:,0].argsort()][-10:]
print(high_range)
# Out:
# [[3.82897043]
#  [4.04098249]
#  [4.49634819]
#  [4.71041276]
#  [4.73032076]
#  [5.06214602]
#  [5.42383959]
#  [5.59185509]
#  [7.10289909]
#  [7.22881942]]

# %%
saleprice_scaled[:,0].argsort()[-10:]
# Out:
# array([ 798,  178,  769,  440, 1046,  803,  898, 1169, 1182,  691],
#       dtype=int64)

# %%
df_train
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# 6             50       RL         85.0    14115   Pave   NaN      IR1
# 7             20       RL         75.0    10084   Pave   NaN      Reg
# 8             60       RL          NaN    10382   Pave   NaN      IR1
# 9             50       RM         51.0     6120   Pave   NaN      Reg
# 10           190       RL         50.0     7420   Pave   NaN      Reg
# 11            20       RL         70.0    11200   Pave   NaN      Reg
# 12            60       RL         85.0    11924   Pave   NaN      IR1
# ...

# %%
df_train.drop([ 798,  178,  769,  440, 1046,  803,  898, 1169, 1182,  691],)
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 1             60       RL         65.0     8450   Pave   NaN      Reg
# 2             20       RL         80.0     9600   Pave   NaN      Reg
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# 6             50       RL         85.0    14115   Pave   NaN      IR1
# 7             20       RL         75.0    10084   Pave   NaN      Reg
# 8             60       RL          NaN    10382   Pave   NaN      IR1
# 9             50       RM         51.0     6120   Pave   NaN      Reg
# 10           190       RL         50.0     7420   Pave   NaN      Reg
# 11            20       RL         70.0    11200   Pave   NaN      Reg
# 12            60       RL         85.0    11924   Pave   NaN      IR1
# ...

# %%
df_train[df_train.reset_index['Id'] in list(saleprice_scaled[:,0].argsort()[-10:])]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-117-319704b5e515> in <module>
# ----> 1 df_train[df_train.reset_index['Id'] in list(saleprice_scaled[:,0].argsort()[-10:])]
#
# TypeError: 'method' object is not subscriptable

# %%
df_train.loc[list(saleprice_scaled[:,0].argsort()[-10:]),:].index.values
# Out:
# array([ 798,  178,  769,  440, 1046,  803,  898, 1169, 1182,  691],
#       dtype=int64)

# %%
df_train.drop([1,2])
# Out:
#       MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# Id
# 3             60       RL         68.0    11250   Pave   NaN      IR1
# 4             70       RL         60.0     9550   Pave   NaN      IR1
# 5             60       RL         84.0    14260   Pave   NaN      IR1
# 6             50       RL         85.0    14115   Pave   NaN      IR1
# 7             20       RL         75.0    10084   Pave   NaN      Reg
# 8             60       RL          NaN    10382   Pave   NaN      IR1
# 9             50       RM         51.0     6120   Pave   NaN      Reg
# 10           190       RL         50.0     7420   Pave   NaN      Reg
# 11            20       RL         70.0    11200   Pave   NaN      Reg
# 12            60       RL         85.0    11924   Pave   NaN      IR1
# 13            20       RL          NaN    12968   Pave   NaN      IR2
# 14            20       RL         91.0    10652   Pave   NaN      IR1
# ...

# %%
sns.distplot(df_train['SalePrice'],fit=norm)

# %%
sns.distplot(np.log(df_train['SalePrice']),fit=norm)

# %%
stats.probplot(df_train['SalePrice'],plot=plt)
# Out:
# ((array([-3.30513952, -3.04793228, -2.90489705, ...,  2.90489705,
#           3.04793228,  3.30513952]),
#   array([ 34900,  35311,  37900, ..., 625000, 745000, 755000], dtype=int64)),
#  (74160.16474519415, 180921.19589041095, 0.9319665641512986))

# %%
pd.Series(len(df_train['TotalBsmtSF']), index=df_train.index)
# Out:
# Id
# 1       1460
# 2       1460
# 3       1460
# 4       1460
# 5       1460
# 6       1460
# 7       1460
# 8       1460
# 9       1460
# 10      1460
# 11      1460
# 12      1460
# 13      1460
# 14      1460
# 15      1460
# 16      1460
# 17      1460
# 18      1460
# 19      1460
# 20      1460
# 21      1460
# 22      1460
# 23      1460
# 24      1460
# 25      1460
# 26      1460
# 27      1460
# 28      1460
# 29      1460
# 30      1460
#         ...
# 1431    1460
# 1432    1460
# 1433    1460
# 1434    1460
# 1435    1460
# 1436    1460
# 1437    1460
# 1438    1460
# 1439    1460
# 1440    1460
# 1441    1460
# 1442    1460
# 1443    1460
# 1444    1460
# 1445    1460
# 1446    1460
# 1447    1460
# 1448    1460
# 1449    1460
# 1450    1460
# 1451    1460
# 1452    1460
# 1453    1460
# 1454    1460
# 1455    1460
# 1456    1460
# 1457    1460
# 1458    1460
# 1459    1460
# 1460    1460
# Length: 1460, dtype: int64

# %%
df_train.loc[df_train['TotalBsmtSF'] > 0,'TotalBsmtSF'] = np.log(df_train['TotalBsmtSF'])

# %%
df_train.loc[df_train['TotalBsmtSF'] == 0,'TotalBsmtSF']
# Out:
# Id
# 18      0.0
# 40      0.0
# 91      0.0
# 103     0.0
# 157     0.0
# 183     0.0
# 260     0.0
# 343     0.0
# 363     0.0
# 372     0.0
# 393     0.0
# 521     0.0
# 533     0.0
# 534     0.0
# 554     0.0
# 647     0.0
# 706     0.0
# 737     0.0
# 750     0.0
# 779     0.0
# 869     0.0
# 895     0.0
# 898     0.0
# 985     0.0
# 1001    0.0
# 1012    0.0
# 1036    0.0
# 1046    0.0
# 1049    0.0
# 1050    0.0
# 1091    0.0
# 1180    0.0
# 1217    0.0
# 1219    0.0
# 1233    0.0
# 1322    0.0
# 1413    0.0
# Name: TotalBsmtSF, dtype: float64

# %%
sns.distplot(df_train[df_train['TotalBsmtSF']>0]['TotalBsmtSF'], fit=norm)

# %% [markdown]
# ### Linear Models

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib

import matplotlib.pyplot as plt
from scipy.stats import skew
from scipy.stats.stats import pearsonr


# %config InlineBackend.figure_format = 'retina' #set 'png' here when working on notebook
# %matplotlib inline

# %%
train = pd.read_csv("train.csv")
test = pd.read_csv("test.csv")

# %%
all_data = pd.concat([train.loc[:,'MSSubClass':'SaleCondition'],test.loc[:,'MSSubClass':'SaleCondition']])

# %%
all_data.head()
# Out:
#    MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0          60       RL         65.0     8450   Pave   NaN      Reg
# 1          20       RL         80.0     9600   Pave   NaN      Reg
# 2          60       RL         68.0    11250   Pave   NaN      IR1
# 3          70       RL         60.0     9550   Pave   NaN      IR1
# 4          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig      ...       ScreenPorch PoolArea PoolQC  \
# 0         Lvl    AllPub    Inside      ...                 0        0    NaN
# 1         Lvl    AllPub       FR2      ...                 0        0    NaN
# 2         Lvl    AllPub    Inside      ...                 0        0    NaN
# 3         Lvl    AllPub    Corner      ...                 0        0    NaN
# 4         Lvl    AllPub       FR2      ...                 0        0    NaN
#
#   Fence MiscFeature MiscVal  MoSold  YrSold  SaleType  SaleCondition
# ...

# %%
#log(price + 1)将偏态数据转为正态
matplotlib.rcParams['figure.figsize'] = (12 , 6)
prices = pd.DataFrame({'price':train['SalePrice'],'log(price + 1)':np.log1p(train['SalePrice'])})
prices.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002219F9DB438>,
# ...
#       dtype=object)

# %%
all_data.dtypes[all_data.dtypes != 'object'].index
# Out:
# Index(['MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2',
#        'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces',
#        'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF',
#        'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal',
#        'MoSold', 'YrSold'],
#       dtype='object')

# %%
train['SalePrice'] = np.log1p(train['SalePrice'])

#筛选数值类型特征用于计算偏态
numeric_feature = all_data.dtypes[all_data.dtypes != 'object'].index
#将偏态>0.75的特征进行log1操作
skewed_feats = train[numeric_feature].apply(lambda x : skew(x.dropna()))#计算偏态
sw_index = skewed_feats[skewed_feats>0.75].index  #取>0.75特征
all_data[sw_index] = np.log1p(all_data[sw_index])

# %%
all_data.shape
# Out:
# (2919, 79)

# %%
#将特征
all_data = pd.get_dummies(all_data)
all_data.shape
# Out:
# (2919, 288)

# %%
all_data.fillna(all_data.mean(),inplace=True)

# %%
#数据集划分
X_train = all_data[:train.shape[0]]
X_test = all_data[train.shape[0]:]
y = train['SalePrice']

# %% [markdown]
# ## 构建模型 Lasso + XGboost

# %%
from sklearn.linear_model import Ridge,RidgeCV,ElasticNet,LassoCV,LassoLarsCV
from sklearn.model_selection import cross_val_score
#均方根误差交叉验证模型评价
def rmse_cv(model):
    rmse = np.sqrt(-cross_val_score(model,X_train,y,scoring = 'neg_mean_squared_error',cv = 5))
    return(rmse)

# %%
model_ridge = Ridge()
#寻找适合正则系数
alphas = [0.05,0.1,0.3,1,3,5,10,15,30,50,75]
cv_ridge = [rmse_cv(Ridge(alpha = alpha)).mean() for alpha in alphas]

cv_ridge = pd.Series(cv_ridge,index = alphas)
cv_ridge.plot()

# %%
cv_ridge.mean()
# Out:
# 0.13159475841045762

# %%
model_lasso = LassoCV(alphas=[1,0.1,0.01,0.005]).fit(X_train,y)
rmse_cv(model_lasso).mean()
# Out:
# 0.14238782841972192

# %%
coef = pd.Series(model_lasso.coef_,index = X_train.columns)
#查看lasso选取的特征

print(sum(coef != 0 ),sum(coef == 0))

imp_coef = pd.concat([coef.sort_values().head(20),coef.sort_values().tail(10)])

imp_coef.plot(kind = 'barh')
# Out:
# MSSubClass              -0.000000
# LotFrontage              0.000000
# LotArea                  0.083040
# OverallQual              0.092300
# OverallCond              0.037678
# YearBuilt                0.002843
# YearRemodAdd             0.001523
# MasVnrArea              -0.000000
# BsmtFinSF1               0.013770
# BsmtFinSF2              -0.000000
# BsmtUnfSF                0.000000
# TotalBsmtSF              0.011980
# 1stFlrSF                 0.048785
# 2ndFlrSF                 0.000000
# LowQualFinSF            -0.000000
# GrLivArea                0.201775
# BsmtFullBath             0.000611
# BsmtHalfBath            -0.000000
# FullBath                 0.000452
# HalfBath                 0.000000
# BedroomAbvGr            -0.000000
# KitchenAbvGr            -0.000000
# TotRmsAbvGrd             0.021870
# Fireplaces               0.039547
# GarageYrBlt             -0.000282
# GarageCars               0.013669
# GarageArea               0.000206
# ...

# %%
#查看预测值与真实值的偏差
preds = pd.DataFrame({'preds':model_lasso.predict(X_train),'true':y})
preds['residuals'] = preds['true'] - preds['preds']
preds.plot(x = 'true',y = 'residuals',kind = 'scatter')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.

# %% [markdown]
# ## XGboost

# %%
import xgboost as xgb

# %%
dtrain = xgb.DMatrix(X_train,label = y)
dtest = xgb.DMatrix(X_test)

params = {'max_depth':2,'eta':0.1}
model = xgb.cv(params,dtrain,num_boost_round=500,early_stopping_rounds=100)
model.loc[30:,["test-rmse-mean", "train-rmse-mean"]].plot()
# Out:
# [12:26:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [12:26:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [12:26:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [12:26:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [12:26:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# [12:26:21] C:\Users\Administrator\Desktop\xgboost\src\tree\updater_prune.cc:74: tree pruning end, 1 roots, 0 extra nodes, 0 pruned nodes, max_depth=0
# ...

# %%
model_xgb = xgb.XGBRegressor(n_estimators=360,max_depth=2,learning_rate=0.1)
model_xgb.fit(X_train,y)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=2, min_child_weight=1, missing=None, n_estimators=360,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %%
xgb_preds = np.expm1(model_xgb.predict(X_test))
lasso_preds = np.expm1(model_lasso.predict(X_test))

# %%
predictions = pd.DataFrame({'Xgb':xgb_preds,'lass':lasso_preds})
sns.scatterplot(x = 'Xgb',y = 'lass',data=predictions)

# %%
preds = 0.7 * lasso_preds + 0.3 * xgb_preds
solution = pd.DataFrame({'id':test.Id,'SalePrice':preds})
solution.to_csv('house_price')
